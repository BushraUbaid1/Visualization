# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Who_time_series = pd.read_csv("Who_time_series.csv")

# %%
Who_time_series
# Out:
#       Date_reported                           Country  New_cases  \
# 0        2020-01-04                             China          1
# 1        2020-01-05                             China          0
# 2        2020-01-06                             China          3
# 3        2020-01-07                             China          0
# 4        2020-01-08                             China          0
# ...             ...                               ...        ...
# 31871    2020-07-31                            Panama       1046
# 31872    2020-07-31                       Timor-Leste          0
# 31873    2020-07-31                         Guatemala       1221
# 31874    2020-07-31  Saint Vincent and the Grenadines          0
# 31875    2020-07-31  Democratic Republic of the Congo         79
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     1           0                  0
# 1                     1           0                  0
# 2                     4           0                  0
# 3                     4           0                  0
# 4                     4           0                  0
# ...                 ...         ...                ...
# 31871             63269          25               1374
# 31872                24           0                  0
# 31873             48826          32               1867
# 31874                52           0                  0
# 31875              9009           2                214
#
# [31876 rows x 6 columns]

# %%
Who_time_series.dtypes
# Out:
# Date_reported        object
# Country              object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
Who_time_series["Date_reported"] = pd.to_datetime(Who_time_series["Date_reported"])

# %%
Who_time_series["Date_reported"].dt.year.value_counts()
# Out:
# 2020    31876
# Name: Date_reported, dtype: int64

# %%
Who_time_series["Date_reported"].dt.month.value_counts().sort_index()
# Out:
# 1     173
# 2     890
# 3    4599
# 4    6355
# 5    6683
# 6    6480
# 7    6696
# Name: Date_reported, dtype: int64

# %%
italy = Who_time_series[Who_time_series["Country"] == "Italy"]

# %%
italy
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 123      2020-01-29   Italy          6                 6           0
# 144      2020-01-30   Italy          0                 6           0
# 158      2020-01-31   Italy          0                 6           0
# 187      2020-02-01   Italy          0                 6           0
# 215      2020-02-02   Italy          0                 6           0
# ...             ...     ...        ...               ...         ...
# 30870    2020-07-27   Italy        254            246118           5
# 31097    2020-07-28   Italy        168            246286           5
# 31333    2020-07-29   Italy        202            246488          11
# 31629    2020-07-30   Italy        288            246776           6
# 31686    2020-07-31   Italy        382            247158           3
#
#        Cumulative_deaths
# 123                    0
# 144                    0
# 158                    0
# 187                    0
# 215                    0
# ...                  ...
# 30870              35107
# 31097              35112
# 31333              35123
# 31629              35129
# 31686              35132
#
# [185 rows x 6 columns]

# %%
plt.plot(italy["Date_reported"], italy["Cumulative_cases"])
plt.title("italy: Cumulative_Reported_cases")
plt.xlabel("Date")
plt.ylabel("Number of cases")
plt.show()
#print("Generally, a quantity that increases very quickly in the begining and then it shows down more and more over time has a logrithemic growth ")
# Out:
# Generally, a quantity that increases very quickly in the begining and then it shows down more and more over time has a logrithemic growth

# %%
india = Who_time_series[Who_time_series["Country"] == "India"]
plt.plot(india["Date_reported"], india["Cumulative_cases"])
plt.title("india: Cumulative_Reported_cases")
plt.xlabel("Date")
plt.ylabel("Number of cases")
plt.ticklabel_format(axis = "y", style = "plain")
plt.show()
print("India Shows Exponential Growth For The Data We Have, But When The Number Of New Cases Will Decrease, The Growth will Become Logrithemic  ")
# Out:
# India Shows Exponential Growth For The Data We Have, But When The Number Of New Cases Will Decrease, The Growth will Become Logrithemic

# %%
def plot_cases(country_name):
    df = Who_time_series[Who_time_series["Country"] == country_name]
    plt.plot(df["Date_reported"], df["Cumulative_cases"])
    plt.title(f"{country_name}: Cumulative_Reported_cases")
    plt.xlabel("Date")
    plt.ylabel("Number of cases")
    plt.ticklabel_format(axis = "y", style = "plain")
    plt.show()
    print("Generally, a quantity that increase constantly over time has Linear Growth")

# %%
plot_cases("Poland")
# Out:
# Generally, a quantity that increase constantly over time has Linear Growth

# %%
countries = Who_time_series["Country"].unique()

# %%
for i in countries[:10]:
    plot_cases(i)
# Out:
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth
# Generally, a quantity that increase constantly over time has Linear Growth

# %%
france = Who_time_series[Who_time_series["Country"] == "France"]
uk= Who_time_series[Who_time_series["Country"] == "The United Kingdom"]
pakistan = Who_time_series[Who_time_series["Country"] == "Pakistan"]

# %%
plt.plot(france["Date_reported"], france["Cumulative_cases"], label = "France")
plt.plot(uk["Date_reported"], uk["Cumulative_cases"], label = "UK")
plt.plot(pakistan["Date_reported"], pakistan["Cumulative_cases"], label = "Pakistan")
plt.legend()
plt.show()
